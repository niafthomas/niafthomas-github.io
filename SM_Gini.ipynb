# %% [markdown]
# <a href="https://colab.research.google.com/github/niafthomas/niafthomas.github.io/blob/main/SM_Gini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
gini = pd.read_csv("gini.csv")
sm = pd.read_csv("Social_Mobility.csv")

# %%
gini
# Out:
#          Country  Gini
# 0    Afghanistan   NaN
# 1        Albania   4.2
# 2        Algeria   4.0
# 3         Angola   9.0
# 4      Argentina   8.8
# ..           ...   ...
# 173    Palestine   5.6
# 174        Yemen   6.1
# 175       Zambia  21.1
# 176     Zimbabwe   8.6
# 177        World   NaN
#
# [178 rows x 2 columns]

# %%
gini = gini.dropna()

# %%
gini
# Out:
#        Country  Gini
# 1      Albania   4.2
# 2      Algeria   4.0
# 3       Angola   9.0
# 4    Argentina   8.8
# 5      Armenia   5.0
# ..         ...   ...
# 172    Vietnam   6.2
# 173  Palestine   5.6
# 174      Yemen   6.1
# 175     Zambia  21.1
# 176   Zimbabwe   8.6
#
# [148 rows x 2 columns]

# %%
sm
# Out:
#         Country  Index Score
# 0       Denmark         85.2
# 1        Norway         83.6
# 2       Finland         83.6
# 3        Sweden         83.5
# 4       Iceland         82.7
# ..          ...          ...
# 77   Bangladesh         40.2
# 78     Pakistan         36.7
# 79     Cameroon         36.0
# 80      Senegal         36.0
# 81  Ivory Coast         34.5
#
# [82 rows x 2 columns]

# %%
df = pd.merge(gini, sm, how='outer', on='Country')

# %%
df
# Out:
#           Country  Gini  Index Score
# 0         Albania   4.2         55.6
# 1         Algeria   4.0          NaN
# 2          Angola   9.0          NaN
# 3       Argentina   8.8         57.3
# 4         Armenia   5.0         53.9
# ..            ...   ...          ...
# 146        Zambia  21.1          NaN
# 147      Zimbabwe   8.6          NaN
# 148     Singapore   NaN         74.6
# 149   New Zealand   NaN         74.3
# 150  Saudi Arabia   NaN         57.1
#
# [151 rows x 3 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#             Country  Gini  Index Score
# 0           Albania   4.2         55.6
# 3         Argentina   8.8         57.3
# 4           Armenia   5.0         53.9
# 5         Australia   6.3         75.1
# 6           Austria   4.9         80.1
# ..              ...   ...          ...
# 138         Ukraine   3.5         61.2
# 139  United Kingdom   5.4         74.4
# 140   United States   9.4         70.4
# 141         Uruguay   7.8         67.1
# 143         Vietnam   6.2         57.8
#
# [79 rows x 3 columns]

# %%
df.to_csv("sm_gini.csv", index = False)

# %%
from google.colab import files

# %%
files.download("sm_gini.csv")
