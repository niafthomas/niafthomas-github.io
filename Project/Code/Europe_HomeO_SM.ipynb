# %% [markdown]
# <a href="https://colab.research.google.com/github/niafthomas/niafthomas.github.io/blob/main/Europe_HomeO_SM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents
import plotly.express as px

# %% [markdown]
# Getting list of European Countries

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_European_countries_by_area"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#    Rank    State  ...                                              Notes Unnamed: 5
# 0   1.0  Russia*  ...  3,995,200 km2 (1,542,600 sq mi) including the ...        NaN
# 1   2.0  Ukraine  ...                                  Including Crimea.        NaN
# 2   3.0  France*  ...  643,801 km2 (248,573 sq mi) when the overseas ...        NaN
# 3   4.0   Spain*  ...  505,990 km2 (195,360 sq mi) when the Canary Is...        NaN
# 4   5.0   Sweden  ...                                                NaN        NaN
#
# [5 rows x 6 columns]

# %%
Countries = df[['State']]
Countries['State'] = Countries['State'].str.replace('*','')
Countries.rename(columns={'State':'Country'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Countries
# Out:
#                    Country
# 0                   Russia
# 1                  Ukraine
# 2                   France
# 3                    Spain
# 4                   Sweden
# 5                   Norway
# 6                  Germany
# 7                  Finland
# 8                   Poland
# 9                    Italy
# 10          United Kingdom
# 11                 Romania
# 12                 Belarus
# 13              Kazakhstan
# 14                  Greece
# 15                Bulgaria
# 16                 Iceland
# 17                 Hungary
# 18                Portugal
# 19                 Austria
# 20          Czech Republic
# 21                  Serbia
# 22                 Ireland
# 23               Lithuania
# 24                  Latvia
# 25                 Croatia
# 26  Bosnia and Herzegovina
# 27                Slovakia
# 28                 Estonia
# 29                 Denmark
# 30             Switzerland
# 31             Netherlands
# 32                 Moldova
# ...

# %% [markdown]
# Data on Social Mobility

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/Global_Social_Mobility_Index"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

# %%
df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#    Rank  Country  Index Score
# 0     1  Denmark         85.2
# 1     2   Norway         83.6
# 2     3  Finland         83.6
# 3     4   Sweden         83.5
# 4     5  Iceland         82.7

# %%
# drop the unwanted columns
sm = df.drop(["Rank"], axis=1)
# rename columns for ease

# %%
sm
# Out:
#         Country  Index Score
# 0       Denmark         85.2
# 1        Norway         83.6
# 2       Finland         83.6
# 3        Sweden         83.5
# 4       Iceland         82.7
# ..          ...          ...
# 77   Bangladesh         40.2
# 78     Pakistan         36.7
# 79     Cameroon         36.0
# 80      Senegal         36.0
# 81  Ivory Coast         34.5
#
# [82 rows x 2 columns]

# %% [markdown]
# Getting Home Ownership data

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_countries_by_home_ownership_rate"
table_class="wikitable sortable jquery-tablesorter"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})
df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#   Country or Territory Home ownership rate(%) Date of Information
# 0              Romania                   96.1             2019[2]
# 1              Hungary                   91.3             2020[2]
# 2             Slovakia                   90.9             2019[2]
# 3            Lithuania                   90.3             2019[2]
# 4                 Cuba                     90             2014[3]

# %%
# drop the unwanted columns
HomeO = df.drop(["Date of Information"], axis=1)
# rename columns for ease
HomeO = data.rename(columns={"Country or Territory": "Country"})
HomeO
# Out:
#                  Country Home ownership rate(%)
# 0                Romania                   96.1
# 1                Hungary                   91.3
# 2               Slovakia                   90.9
# 3              Lithuania                   90.3
# 4                   Cuba                     90
# ..                   ...                    ...
# 66           Switzerland                   41.6
# 67  United Arab Emirates                     28
# 68               Nigeria                     25
# 69                  Fiji                     10
# 70           North Korea                   0[a]
#
# [71 rows x 2 columns]

# %%
merge = pd.merge(Countries, HomeO, on='Country', how='left')

# %%
merged = pd.merge(merge, sm, on='Country', how='left')

# %%
merged
# Out:
#                    Country Home ownership rate(%)  Index Score
# 0                   Russia                     89         64.7
# 1                  Ukraine                    NaN         61.2
# 2                   France                   64.1         76.7
# 3                    Spain                   76.2         70.0
# 4                   Sweden                   64.5         83.5
# 5                   Norway                   80.3         83.6
# 6                  Germany                   51.1         78.8
# 7                  Finland                   70.7         83.6
# 8                   Poland                   84.2         69.1
# 9                    Italy                   72.4         67.4
# 10          United Kingdom                     63         74.4
# 11                 Romania                   96.1         63.1
# 12                 Belarus                    NaN          NaN
# 13              Kazakhstan                    NaN         64.8
# ...

# %%
#drop unwanted columns and set country as index
merged = merged.dropna().set_index('Country')

# %%
merged
# Out:
#                Home ownership rate(%)  Index Score
# Country
# Russia                             89         64.7
# France                           64.1         76.7
# Spain                            76.2         70.0
# Sweden                           64.5         83.5
# Norway                           80.3         83.6
# Germany                          51.1         78.8
# Finland                          70.7         83.6
# Poland                           84.2         69.1
# Italy                            72.4         67.4
# United Kingdom                     63         74.4
# Romania                          96.1         63.1
# Greece                           74.6         59.8
# Bulgaria                         84.3         63.8
# Iceland                          73.6         82.7
# Hungary                          91.3         65.8
# Portugal                         73.9         72.0
# Austria                          55.3         80.1
# ...

# %%
merged.to_csv("Europe_HomeO_SM.csv")
